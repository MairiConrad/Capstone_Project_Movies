# %%
import pandas as pd
import numpy as np

# %%
name_basic = pd.read_csv('./imdb_CSVs/Names_Basic_Pandas.csv')
name_basic
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12410612  nm9993714   Romeo del Rosario        \N        \N
# 12410613  nm9993716       Essias Loberg        \N        \N
# 12410614  nm9993717  Harikrishnan Rajan        \N        \N
# 12410615  nm9993718         Aayush Nair        \N        \N
# 12410616  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
name_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12410617 entries, 0 to 12410616
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 568.1+ MB

# %%
df = pd.DataFrame(name_basic)
df
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12410612  nm9993714   Romeo del Rosario        \N        \N
# 12410613  nm9993716       Essias Loberg        \N        \N
# 12410614  nm9993717  Harikrishnan Rajan        \N        \N
# 12410615  nm9993718         Aayush Nair        \N        \N
# 12410616  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
name_drop = df.drop("birthYear", axis = 'columns')
name_drop
# Out:
#              nconst         primaryName deathYear  \
# 0         nm0000001        Fred Astaire      1987
# 1         nm0000002       Lauren Bacall      2014
# 2         nm0000003     Brigitte Bardot        \N
# 3         nm0000004        John Belushi      1982
# 4         nm0000005      Ingmar Bergman      2007
# ...             ...                 ...       ...
# 12410612  nm9993714   Romeo del Rosario        \N
# 12410613  nm9993716       Essias Loberg        \N
# 12410614  nm9993717  Harikrishnan Rajan        \N
# 12410615  nm9993718         Aayush Nair        \N
# 12410616  nm9993719          Andre Hill        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# ...

# %%
name_drop2 = name_drop.drop("deathYear", axis = 'columns')
name_drop2
# Out:
#              nconst         primaryName                    primaryProfession  \
# 0         nm0000001        Fred Astaire       soundtrack,actor,miscellaneous
# 1         nm0000002       Lauren Bacall                   actress,soundtrack
# 2         nm0000003     Brigitte Bardot  actress,soundtrack,music_department
# 3         nm0000004        John Belushi              actor,soundtrack,writer
# 4         nm0000005      Ingmar Bergman                writer,director,actor
# ...             ...                 ...                                  ...
# 12410612  nm9993714   Romeo del Rosario  animation_department,art_department
# 12410613  nm9993716       Essias Loberg                                  NaN
# 12410614  nm9993717  Harikrishnan Rajan                      cinematographer
# 12410615  nm9993718         Aayush Nair                      cinematographer
# 12410616  nm9993719          Andre Hill                                  NaN
#
# ...

# %%
name_drop2.to_csv('./imdb_CSVs/Final_CSVs/Name_Basic_to_SSIS.csv', index=False, sep=',')

# %%
title_basic = pd.read_csv('./imdb_CSVs/Titles_Basic_Pandas.csv')
title_basic.head()
# Out:
# C:\Users\mairi\AppData\Local\Temp\ipykernel_31012\2276481561.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_basic = pd.read_csv('./imdb_CSVs/Titles_Basic_Pandas.csv')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# ...

# %%
title_basic[title_basic['isAdult']==1].count()
# Out:
# tconst            301421
# titleType         301421
# primaryTitle      301421
# originalTitle     301421
# isAdult           301421
# startYear         301421
# endYear           301421
# runtimeMinutes    301421
# genres            301421
# dtype: int64

# %%
title_drop2 = title_basic.drop("isAdult", axis = 'columns')
title_drop2.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   startYear endYear runtimeMinutes                    genres
# 0      1894      \N              1         Documentary,Short
# 1      1892      \N              5           Animation,Short
# 2      1892      \N              4  Animation,Comedy,Romance
# 3      1892      \N             12           Animation,Short
# 4      1893      \N              1              Comedy,Short

# %%
title_drop3 = title_drop2.drop("endYear", axis = 'columns')
title_drop3.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   startYear runtimeMinutes                    genres
# 0      1894              1         Documentary,Short
# 1      1892              5           Animation,Short
# 2      1892              4  Animation,Comedy,Romance
# 3      1892             12           Animation,Short
# 4      1893              1              Comedy,Short

# %%
title_drop4 = title_drop3.drop("runtimeMinutes", axis = 'columns')
title_drop4.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   startYear                    genres
# 0      1894         Documentary,Short
# 1      1892           Animation,Short
# 2      1892  Animation,Comedy,Romance
# 3      1892           Animation,Short
# 4      1893              Comedy,Short

# %%
movie_title_pdrop = title_drop4[(title_drop4['titleType']== 'movie')]
movie_title_pdrop
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 498      tt0000502     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# ...            ...       ...
# 9737821  tt9916622     movie
# 9737848  tt9916680     movie
# 9737860  tt9916706     movie
# 9737870  tt9916730     movie
# 9737880  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 498                                               Bohemios
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# ...                                                    ...
# 9737821        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9737848  De la ilusión al desconcierto: cine colombiano...
# 9737860                                    Dankyavar Danka
# ...

# %%
movie_title_pdrop.to_csv('./imdb_CSVs/Final_CSVs/Movie_Title_to_SSIS.csv', index=False, sep=',')

# %%
title_crew = pd.read_csv('./imdb_CSVs/Title_Crew_Pandas.csv')
title_crew
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 9737925  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9737926  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9737927  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9737928  tt9916856           nm10538645                      nm6951431
# 9737929  tt9916880            nm0996406            nm1482639,nm2586970
#
# [9737930 rows x 3 columns]

# %%
title_principals = pd.read_csv('./imdb_CSVs/Title_Principals_Pandas.csv')
title_principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
title_principals.shape
# Out:
# (55413272, 6)

# %%
title_principals_drop = title_principals.drop("characters", axis = 'columns')
title_principals_drop
# Out:
#              tconst  ordering      nconst         category  \
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 55413267  tt9916880         4  nm10535738          actress
# 55413268  tt9916880         5   nm0996406         director
# 55413269  tt9916880         6   nm1482639           writer
# 55413270  tt9916880         7   nm2586970           writer
# 55413271  tt9916880         8   nm1594058         producer
#
#                               job
# 0                              \N
# 1                              \N
# 2         director of photography
# 3                              \N
# 4                              \N
# ...                           ...
# ...

# %%
title_principals_drop2 = title_principals_drop.drop("job", axis = 'columns')
title_principals_drop2
# Out:
#              tconst  ordering      nconst         category
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 55413267  tt9916880         4  nm10535738          actress
# 55413268  tt9916880         5   nm0996406         director
# 55413269  tt9916880         6   nm1482639           writer
# 55413270  tt9916880         7   nm2586970           writer
# 55413271  tt9916880         8   nm1594058         producer
#
# [55413272 rows x 4 columns]

# %%
title_principals_drop2.to_csv('./imdb_CSVs/Final_CSVs/title_principals_to_SSIS.csv', index=False, sep=',')

# %%
title_crew.to_csv('./imdb_CSVs/Final_CSVs/title_crew_to_SSIS.csv', index=False, sep=',')

# %%
title_ratings = pd.read_csv('./imdb_CSVs/Title_Ratings_Pandas.csv')
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1966
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1804
# 3  tt0000004            5.6       179
# 4  tt0000005            6.2      2604

# %%
title_ratings_drop = title_ratings.drop("numVotes", axis = 'columns')
title_ratings_drop
# Out:
#             tconst  averageRating
# 0        tt0000001            5.7
# 1        tt0000002            5.8
# 2        tt0000003            6.5
# 3        tt0000004            5.6
# 4        tt0000005            6.2
# ...            ...            ...
# 1295773  tt9916730            8.3
# 1295774  tt9916766            7.0
# 1295775  tt9916778            7.2
# 1295776  tt9916840            8.8
# 1295777  tt9916880            8.2
#
# [1295778 rows x 2 columns]

# %%
title_ratings_drop.to_csv('./imdb_CSVs/Final_CSVs/title_ratings_to_SSIS.csv', index=False, sep=',')

# %%
test = pd.read_csv('./imdb_CSVs/Final_CSVs/title_crew_to_SSIS.csv')
test.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
test.shape
# Out:
# (9737928, 3)

# %%
max(test['directors'].str.len())
# Out:
# 4481

# %%
print(test[test.directors.str.len() == 4481])
# Out:
#            tconst                                          directors  \
# 467495  tt0486531  nm0275908,nm0091840,nm0717064,nm1638539,nm1047...
#
#                                                   writers
# 467495  nm5880947,nm1341518,nm0114182,nm0119607,nm3436...

# %%
max(test['writers'].str.len())
# Out:
# 8224

# %%
print(test[test.writers.str.len() == 11818])
# Out:
#              tconst                                          directors  \
# 3830732  tt15238242  nm12384691,nm12391537,nm14033682,nm12857745,nm...
#
#                                                    writers
# 3830732  nm13176475,nm13201888,nm13186843,nm13201885,nm...

# %%
princ = pd.read_csv('./imdb_CSVs/Final_CSVs/title_principals_to_SSIS.csv')
princ.head()
# Out:
#       tconst  ordering     nconst         category
# 0  tt0000001         1  nm1588970             self
# 1  tt0000001         2  nm0005690         director
# 2  tt0000001         3  nm0374658  cinematographer
# 3  tt0000002         1  nm0721526         director
# 4  tt0000002         2  nm1335271         composer

# %%
dropped = pd.read_csv('./imdb_CSVs/Final_CSVs/Movie_Title_to_SSIS.csv')
dropped.head()
# Out:
#       tconst titleType                   primaryTitle  \
# 0  tt0000009     movie                     Miss Jerry
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 2  tt0000502     movie                       Bohemios
# 3  tt0000574     movie    The Story of the Kelly Gang
# 4  tt0000591     movie               The Prodigal Son
#
#                    originalTitle startYear                      genres
# 0                     Miss Jerry      1894                     Romance
# 1  The Corbett-Fitzsimmons Fight      1897      Documentary,News,Sport
# 2                       Bohemios      1905                          \N
# 3    The Story of the Kelly Gang      1906  Action,Adventure,Biography
# 4              L'enfant prodigue      1907                       Drama

# %%
dropped.join(princ, how= 'inner', lsuffix= 'tconst', rsuffix = 'tconst')
# Out:
#        tconsttconst titleType  \
# 0         tt0000009     movie
# 1         tt0000147     movie
# 2         tt0000502     movie
# 3         tt0000574     movie
# 4         tt0000591     movie
# ...             ...       ...
# 640829    tt9916622     movie
# 640830    tt9916680     movie
# 640831    tt9916706     movie
# 640832    tt9916730     movie
# 640833    tt9916754     movie
#
#                                              primaryTitle  \
# 0                                              Miss Jerry
# 1                           The Corbett-Fitzsimmons Fight
# 2                                                Bohemios
# 3                             The Story of the Kelly Gang
# 4                                        The Prodigal Son
# ...                                                   ...
# 640829        Rodolpho Teóphilo - O Legado de um Pioneiro
# 640830  De la ilusión al desconcierto: cine colombiano...
# 640831                                    Dankyavar Danka
# ...
